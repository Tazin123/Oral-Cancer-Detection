# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.8/702.8 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=/content/drive/MyDrive/v8/yolov8x.pt data=/content/drive/MyDrive/v8/data.yml epochs=800 imgsz=224
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/v8/runs/detect/train3/weights/best.pt conf=0.10 source=/content/drive/MyDrive/v8/data/test/images
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/88 /content/drive/MyDrive/v8/data/test/images/cancer_101.jpg: 224x224 54 cancers, 23.8ms
# image 2/88 /content/drive/MyDrive/v8/data/test/images/cancer_11.jpg: 224x224 57 cancers, 23.8ms
# image 3/88 /content/drive/MyDrive/v8/data/test/images/cancer_110.jpg: 224x224 57 cancers, 23.6ms
# image 4/88 /content/drive/MyDrive/v8/data/test/images/cancer_112.jpg: 224x224 68 cancers, 38 non-cancers, 23.7ms
# image 5/88 /content/drive/MyDrive/v8/data/test/images/cancer_113.jpg: 224x224 57 cancers, 13 non-cancers, 23.6ms
# image 6/88 /content/drive/MyDrive/v8/data/test/images/cancer_139.jpg: 224x224 57 cancers, 23.3ms
# image 7/88 /content/drive/MyDrive/v8/data/test/images/cancer_141.jpg: 224x224 55 cancers, 17.5ms
# image 8/88 /content/drive/MyDrive/v8/data/test/images/cancer_146.jpg: 224x224 59 cancers, 17.6ms
# ...

# %%
import shutil

folder_path = '/content/runs'
shutil.make_archive('/content/run', 'zip', folder_path)
# Out:
# '/content/run.zip'

# %%
from google.colab import files

files.download('/content/run.zip')
